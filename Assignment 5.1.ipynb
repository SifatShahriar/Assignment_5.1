# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Transformation.csv")

# %%
df.head()
# Out:
#    Price
# 0    110
# 1    105
# 2    115
# 3    120
# 4    110

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   9 non-null      int64
# dtypes: int64(1)
# memory usage: 200.0 bytes

# %%
mean_df = df.Price.mean()

# %%
mean_df
# Out:
# 116.11111111111111

# %%
median_df = df.Price.median()

# %%
median_df
# Out:
# 110.0

# %%
mode_df = df.Price.mode()

# %%
mode_df
# Out:
# 0    105
# 1    110
# Name: Price, dtype: int64

# %%
std_df = df.Price.std()

# %%
std_df
# Out:
# 15.567951410224504

# %%
q1 = df.Price.quantile(0.25)

# %%
q1
# Out:
# 105.0

# %%
q2 = df.Price.quantile(0.5)

# %%
q2
# Out:
# 110.0

# %%
q3 = df.Price.quantile(0.75)

# %%
q3
# Out:
# 120.0

# %%
iqr = q3 - q1

# %%
iqr
# Out:
# 15.0

# %% [markdown]
# ### Standardization Auto

# %%
from sklearn.preprocessing import StandardScaler
std_scaler = StandardScaler()

# %%
df['Std_auto'] = std_scaler.fit_transform(df[["Price"]])

# %%
df
# Out:
#    Price  Std_auto
# 0    110 -0.416356
# 1    105 -0.757011
# 2    115 -0.075701
# 3    120  0.264954
# 4    110 -0.416356
# 5    130  0.946264
# 6    150  2.308884
# 7    100 -1.097666
# 8    105 -0.757011

# %%
df['Price'].describe()
# Out:
# count      9.000000
# mean     116.111111
# std       15.567951
# min      100.000000
# 25%      105.000000
# 50%      110.000000
# 75%      120.000000
# max      150.000000
# Name: Price, dtype: float64

# %%
df['Std_auto'].describe()
# Out:
# count    9.000000e+00
# mean    -2.343804e-16
# std      1.060660e+00
# min     -1.097666e+00
# 25%     -7.570112e-01
# 50%     -4.163561e-01
# 75%      2.649539e-01
# max      2.308884e+00
# Name: Std_auto, dtype: float64

# %% [markdown]
# ### Standardization Manual

# %%
df['std_manual'] = (df['Price'] - mean_df)/df.Price.std(ddof=0) #default = ddof (0)

# %%
df
# Out:
#    Price  Std_auto  std_manual
# 0    110 -0.416356   -0.416356
# 1    105 -0.757011   -0.757011
# 2    115 -0.075701   -0.075701
# 3    120  0.264954    0.264954
# 4    110 -0.416356   -0.416356
# 5    130  0.946264    0.946264
# 6    150  2.308884    2.308884
# 7    100 -1.097666   -1.097666
# 8    105 -0.757011   -0.757011

# %% [markdown]
# ### MinMaxScaling Auto

# %%
from sklearn.preprocessing import MinMaxScaler
mmscaler = MinMaxScaler()

# %%
df['minMax_auto'] = mmscaler.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Std_auto  std_manual  minMax_auto
# 0    110 -0.416356   -0.416356          0.2
# 1    105 -0.757011   -0.757011          0.1
# 2    115 -0.075701   -0.075701          0.3
# 3    120  0.264954    0.264954          0.4
# 4    110 -0.416356   -0.416356          0.2
# 5    130  0.946264    0.946264          0.6
# 6    150  2.308884    2.308884          1.0
# 7    100 -1.097666   -1.097666          0.0
# 8    105 -0.757011   -0.757011          0.1

# %% [markdown]
# ### MinMaxScaling Manual

# %%
df['minMax_manual'] = (df.Price - df.Price.min()) / (df.Price.max()-df.Price.min())

# %%
df
# Out:
#    Price  Std_auto  std_manual  minMax_auto  minMax_manual
# 0    110 -0.416356   -0.416356          0.2            0.2
# 1    105 -0.757011   -0.757011          0.1            0.1
# 2    115 -0.075701   -0.075701          0.3            0.3
# 3    120  0.264954    0.264954          0.4            0.4
# 4    110 -0.416356   -0.416356          0.2            0.2
# 5    130  0.946264    0.946264          0.6            0.6
# 6    150  2.308884    2.308884          1.0            1.0
# 7    100 -1.097666   -1.097666          0.0            0.0
# 8    105 -0.757011   -0.757011          0.1            0.1

# %% [markdown]
# ### Max Absolute Scaler Auto

# %%
from sklearn.preprocessing import MaxAbsScaler
MaScaler = MaxAbsScaler()

# %%
df['MaScaler_Auto'] = MaScaler.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Std_auto  std_manual  minMax_auto  minMax_manual  MaScaler_Auto
# 0    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 1    105 -0.757011   -0.757011          0.1            0.1       0.700000
# 2    115 -0.075701   -0.075701          0.3            0.3       0.766667
# 3    120  0.264954    0.264954          0.4            0.4       0.800000
# 4    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 5    130  0.946264    0.946264          0.6            0.6       0.866667
# 6    150  2.308884    2.308884          1.0            1.0       1.000000
# 7    100 -1.097666   -1.097666          0.0            0.0       0.666667
# 8    105 -0.757011   -0.757011          0.1            0.1       0.700000

# %% [markdown]
# ### Max Absolute Scaler Manual

# %%
df['MaScaler_Manual'] = df.Price / np.abs(df.Price.max())

# %%
df
# Out:
#    Price  Std_auto  std_manual  minMax_auto  minMax_manual  MaScaler_Auto  \
# 0    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 1    105 -0.757011   -0.757011          0.1            0.1       0.700000
# 2    115 -0.075701   -0.075701          0.3            0.3       0.766667
# 3    120  0.264954    0.264954          0.4            0.4       0.800000
# 4    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 5    130  0.946264    0.946264          0.6            0.6       0.866667
# 6    150  2.308884    2.308884          1.0            1.0       1.000000
# 7    100 -1.097666   -1.097666          0.0            0.0       0.666667
# 8    105 -0.757011   -0.757011          0.1            0.1       0.700000
#
#    MaScaler_Manual
# 0         0.733333
# 1         0.700000
# 2         0.766667
# 3         0.800000
# 4         0.733333
# 5         0.866667
# 6         1.000000
# 7         0.666667
# 8         0.700000

# %% [markdown]
# ### Robust Scaler Auto

# %%
from sklearn.preprocessing import RobustScaler
rScaler = RobustScaler()

# %%
df["rScaler_Auto"] = rScaler.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Std_auto  std_manual  minMax_auto  minMax_manual  MaScaler_Auto  \
# 0    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 1    105 -0.757011   -0.757011          0.1            0.1       0.700000
# 2    115 -0.075701   -0.075701          0.3            0.3       0.766667
# 3    120  0.264954    0.264954          0.4            0.4       0.800000
# 4    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 5    130  0.946264    0.946264          0.6            0.6       0.866667
# 6    150  2.308884    2.308884          1.0            1.0       1.000000
# 7    100 -1.097666   -1.097666          0.0            0.0       0.666667
# 8    105 -0.757011   -0.757011          0.1            0.1       0.700000
#
#    MaScaler_Manual  rScaler_Auto
# 0         0.733333      0.000000
# 1         0.700000     -0.333333
# 2         0.766667      0.333333
# 3         0.800000      0.666667
# 4         0.733333      0.000000
# 5         0.866667      1.333333
# 6         1.000000      2.666667
# 7         0.666667     -0.666667
# 8         0.700000     -0.333333

# %% [markdown]
# ### Robust Scaler Manual

# %%
df["rScaler_Manual"] = (df.Price - median_df)/iqr

# %%
df
# Out:
#    Price  Std_auto  std_manual  minMax_auto  minMax_manual  MaScaler_Auto  \
# 0    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 1    105 -0.757011   -0.757011          0.1            0.1       0.700000
# 2    115 -0.075701   -0.075701          0.3            0.3       0.766667
# 3    120  0.264954    0.264954          0.4            0.4       0.800000
# 4    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 5    130  0.946264    0.946264          0.6            0.6       0.866667
# 6    150  2.308884    2.308884          1.0            1.0       1.000000
# 7    100 -1.097666   -1.097666          0.0            0.0       0.666667
# 8    105 -0.757011   -0.757011          0.1            0.1       0.700000
#
#    MaScaler_Manual  rScaler_Auto  rScaler_Manual
# 0         0.733333      0.000000        0.000000
# 1         0.700000     -0.333333       -0.333333
# 2         0.766667      0.333333        0.333333
# 3         0.800000      0.666667        0.666667
# 4         0.733333      0.000000        0.000000
# 5         0.866667      1.333333        1.333333
# 6         1.000000      2.666667        2.666667
# 7         0.666667     -0.666667       -0.666667
# 8         0.700000     -0.333333       -0.333333

# %% [markdown]
# ### Log Transform Auto

# %%
from sklearn.preprocessing import FunctionTransformer
LT = FunctionTransformer(func=np.log1p)

# %%
df['LT_1p_Auto'] = LT.fit_transform(df[['Price']])

# %%
df
# Out:
#    Price  Std_auto  std_manual  minMax_auto  minMax_manual  MaScaler_Auto  \
# 0    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 1    105 -0.757011   -0.757011          0.1            0.1       0.700000
# 2    115 -0.075701   -0.075701          0.3            0.3       0.766667
# 3    120  0.264954    0.264954          0.4            0.4       0.800000
# 4    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 5    130  0.946264    0.946264          0.6            0.6       0.866667
# 6    150  2.308884    2.308884          1.0            1.0       1.000000
# 7    100 -1.097666   -1.097666          0.0            0.0       0.666667
# 8    105 -0.757011   -0.757011          0.1            0.1       0.700000
#
#    MaScaler_Manual  rScaler_Auto  rScaler_Manual  LT_1p_Auto
# 0         0.733333      0.000000        0.000000    4.709530
# 1         0.700000     -0.333333       -0.333333    4.663439
# 2         0.766667      0.333333        0.333333    4.753590
# 3         0.800000      0.666667        0.666667    4.795791
# 4         0.733333      0.000000        0.000000    4.709530
# 5         0.866667      1.333333        1.333333    4.875197
# 6         1.000000      2.666667        2.666667    5.017280
# 7         0.666667     -0.666667       -0.666667    4.615121
# 8         0.700000     -0.333333       -0.333333    4.663439

# %% [markdown]
# ### Log Transformer Manual

# %%
df['LT_1p_Manual'] = np.log1p(df.Price)

# %%
df
# Out:
#    Price  Std_auto  std_manual  minMax_auto  minMax_manual  MaScaler_Auto  \
# 0    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 1    105 -0.757011   -0.757011          0.1            0.1       0.700000
# 2    115 -0.075701   -0.075701          0.3            0.3       0.766667
# 3    120  0.264954    0.264954          0.4            0.4       0.800000
# 4    110 -0.416356   -0.416356          0.2            0.2       0.733333
# 5    130  0.946264    0.946264          0.6            0.6       0.866667
# 6    150  2.308884    2.308884          1.0            1.0       1.000000
# 7    100 -1.097666   -1.097666          0.0            0.0       0.666667
# 8    105 -0.757011   -0.757011          0.1            0.1       0.700000
#
#    MaScaler_Manual  rScaler_Auto  rScaler_Manual  LT_1p_Auto  LT_1p_Manual
# 0         0.733333      0.000000        0.000000    4.709530      4.709530
# 1         0.700000     -0.333333       -0.333333    4.663439      4.663439
# 2         0.766667      0.333333        0.333333    4.753590      4.753590
# 3         0.800000      0.666667        0.666667    4.795791      4.795791
# 4         0.733333      0.000000        0.000000    4.709530      4.709530
# 5         0.866667      1.333333        1.333333    4.875197      4.875197
# 6         1.000000      2.666667        2.666667    5.017280      5.017280
# 7         0.666667     -0.666667       -0.666667    4.615121      4.615121
# 8         0.700000     -0.333333       -0.333333    4.663439      4.663439
